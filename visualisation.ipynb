# %% [markdown]
# ## Importing the required Libraries and Dataset

# %%
# for data handling
import pandas as pd

# visualisation
import plotly
import plotly.express as px
import plotly.io as pio

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("spotify.csv")
# avb = pd.read_csv("avb.csv")
# beatles = pd.read_csv("beatles.csv")
# df_new = pd.concat([df, avb, beatles])
# df_new.drop("Unnamed: 0", axis=1, inplace=True)
# df_new.to_csv("spotify.csv")

# %% [markdown]
# ## Explore the Dataset

# %%
df.head(3)
# Out:
#    Unnamed: 0                     album artist_name  track_number  \
# 0           0                 El Dorado    24kGoldn             1
# 1           1  Fighting Demons (Deluxe)  Juice WRLD             1
# 2           2                 El Dorado    24kGoldn             2
#
#                        id                    name  \
# 0  38mQZ5tZ6IylQaJCCF90ox                 The Top
# 1  1X8E4vVoOM3BpSQlEDSjjM                    Burn
# 2  3JVTsvTldB6arHVlmxmTnM  Company (feat. Future)
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:38mQZ5tZ6IylQaJCCF90ox         0.336         0.754   0.711
# 1  spotify:track:1X8E4vVoOM3BpSQlEDSjjM         0.149         0.354   0.475
# 2  spotify:track:3JVTsvTldB6arHVlmxmTnM         0.447         0.831   0.727
#
#    ...  liveness  loudness  speechiness    tempo  valence  explicit mode  \
# 0  ...     0.128    -3.842       0.0720  138.031   0.2700      True  0.0
# ...

# %%
df.tail(3)
# Out:
#        Unnamed: 0                  album  artist_name  track_number  \
# 16110         475  Revolver (Remastered)  The Beatles            12
# 16111         476  Revolver (Remastered)  The Beatles            13
# 16112         477  Revolver (Remastered)  The Beatles            14
#
#                            id                                           name  \
# 16110  7orb0y6ySGdsYZywMoQtsD           I Want To Tell You - Remastered 2009
# 16111  3tGhRLgcCP6SIZU3tbGl7l  Got To Get You Into My Life - Remastered 2009
# 16112  00oZhqZIQfL9P5CjOP6JsO         Tomorrow Never Knows - Remastered 2009
#
#                                         uri  acousticness  danceability  \
# 16110  spotify:track:7orb0y6ySGdsYZywMoQtsD      0.182000         0.493
# 16111  spotify:track:3tGhRLgcCP6SIZU3tbGl7l      0.420000         0.521
# 16112  spotify:track:00oZhqZIQfL9P5CjOP6JsO      0.000084         0.380
#
#        energy  ...  liveness  loudness  speechiness    tempo  valence  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'album', 'artist_name', 'track_number', 'id', 'name',
#        'uri', 'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'explicit',
#        'mode', 'popularity', 'duration_ms', 'Unnamed: 0.1'],
#       dtype='object')

# %%
# Dropping the Unnamed column
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                       album artist_name  track_number                      id  \
# 0                 El Dorado    24kGoldn             1  38mQZ5tZ6IylQaJCCF90ox
# 1  Fighting Demons (Deluxe)  Juice WRLD             1  1X8E4vVoOM3BpSQlEDSjjM
# 2                 El Dorado    24kGoldn             2  3JVTsvTldB6arHVlmxmTnM
#
#                      name                                   uri  acousticness  \
# 0                 The Top  spotify:track:38mQZ5tZ6IylQaJCCF90ox         0.336
# 1                    Burn  spotify:track:1X8E4vVoOM3BpSQlEDSjjM         0.149
# 2  Company (feat. Future)  spotify:track:3JVTsvTldB6arHVlmxmTnM         0.447
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.754   0.711             0.000     0.128    -3.842       0.0720
# 1         0.354   0.475             0.034     0.210    -9.333       0.0425
# 2         0.831   0.727             0.000     0.111    -3.657       0.1690
#
# ...

# %%
df.describe()
# Out:
#        track_number  acousticness  danceability        energy  \
# count  16113.000000  16113.000000  16113.000000  16113.000000
# mean       9.569478      0.247861      0.577129      0.642099
# std        7.204276      0.298221      0.165858      0.230437
# min        1.000000      0.000001      0.000000      0.000261
# 25%        4.000000      0.014700      0.466000      0.485000
# 50%        8.000000      0.102000      0.589000      0.674000
# 75%       13.000000      0.405000      0.697000      0.832000
# max       50.000000      0.996000      0.983000      0.999000
#
#        instrumentalness     liveness      loudness   speechiness  \
# count      16113.000000  16113.00000  16113.000000  16113.000000
# mean           0.083234      0.26324     -7.800583      0.109103
# std            0.228557      0.24515      4.334493      0.137895
# min            0.000000      0.00000    -43.433000      0.000000
# 25%            0.000000      0.10300     -9.215000      0.038000
# ...

# %%
print("No. of songs (rows) in the DataFrame: " + str(len(df)))
print("No. of columns in the DataFrame: " + str(df.shape[1]))
# Out:
# No. of songs (rows) in the DataFrame: 16113
# No. of columns in the DataFrame: 20

# %%
# name of all of the artists
df['artist_name'].unique()
# Out:
# array(['24kGoldn', 'Juice WRLD', 'Jack Harlow', 'Bon Jovi',
#        'Jon Bon Jovi', 'Future', 'Halsey', 'Aerosmith', 'Post Malone',
#        'Doja Cat', 'David Bowie', 'Britney Spears', 'Mike Garson',
#        'Jon Bellion', 'The Beach Boys', 'AREA21', 'Martin Garrix',
#        'Maroon 5', 'The Chainsmokers', 'Drake', 'The Rolling Stones',
#        'Ariana Grande', 'Madonna', 'John Mayer', 'Linkin Park',
#        'Selena Gomez & The Scene', 'Selena Gomez', 'Nicki Minaj',
#        'Green Day', 'Billie Joe Armstrong', 'Hayley Williams', 'The 1975',
#        'Cardi B', 'Bebe Rexha', 'Megan Thee Stallion', '21 Savage',
#        'X Ambassadors', 'Metro Boomin', 'blink-182', 'The Vamps', 'Kygo',
#        'WALK THE MOON', 'Kesha', 'Kodaline', 'Dua Lipa', 'Passenger',
#        'Charlie Puth', 'Panic! At The Disco', 'Ed Sheeran', 'Snow Patrol',
#        'King Biscuit Time', 'Shawn Mendes', 'Demi Lovato', 'Travis Scott',
#        'Huncho Jack', 'Troye Sivan', 'Taylor Swift', 'Khalid',
# ...

# %%
# total number of songs per artist
df['artist_name'].value_counts()
# Out:
# The Beach Boys                           687
# Armin Van Buuren                         557
# The Beatles                              478
# David Bowie                              390
# Hardwell                                 266
#                                         ...
# KIDS SEE GHOSTS                            7
# Ruel                                       7
# Bradley Cooper                             4
# Graham Lyle                                4
# David Guetta - Nicki Minaj - Flo Rida      1
# Name: artist_name, Length: 187, dtype: int64
