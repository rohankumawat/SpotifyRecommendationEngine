# %%
import pandas as pd
import time
import numpy as np

#To access Spotify authorised data we need to create our credentials like clientid and client_secret as well as spotify object to access the API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_id = '17ce462f699045c185314d3e1e983bb2'
client_secret = '3b77a90265984057908ccf77b5460488'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
result = sp.search("Halsey")
result['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#   'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#   'id': '69GGBxA162lTqCwzJG5jLp',
#   'name': 'The Chainsmokers',
#   'type': 'artist',
#   'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#   'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#   'id': '26VFTg2z8YR0cCuwLzESi2',
#   'name': 'Halsey',
#   'type': 'artist',
#   'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}]

# %%
result['tracks']['items'][0]['artists'][0]['uri']
# Out:
# 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'

# %%
# to get related artists
sp.artist_related_artists("spotify:artist:4MCBfE4596Uoi2O4DtmEMz")
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1iJdyDcY98X3GMnUesl7tf'},
#    'followers': {'href': None, 'total': 1941351},
#    'genres': ['rap', 'trap', 'underground hip hop', 'vapor trap', 'viral rap'],
#    'href': 'https://api.spotify.com/v1/artists/1iJdyDcY98X3GMnUesl7tf',
#    'id': '1iJdyDcY98X3GMnUesl7tf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb60856d0ff26e88db35e825ff',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517460856d0ff26e88db35e825ff',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17860856d0ff26e88db35e825ff',
#      'width': 160}],
#    'name': 'Comethazine',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:1iJdyDcY98X3GMnUesl7tf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
# ...

# %%
# spotify community recommendation
sp.recommendations(seed_artists=["spotify:artist:4MCBfE4596Uoi2O4DtmEMz", "spotify:artist:26VFTg2z8YR0cCuwLzESi2"])
# Out:
# {'tracks': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63yrD80RY3RNEM2YDpUpO8'},
#       'href': 'https://api.spotify.com/v1/artists/63yrD80RY3RNEM2YDpUpO8',
#       'id': '63yrD80RY3RNEM2YDpUpO8',
#       'name': 'Melanie Martinez',
#       'type': 'artist',
#       'uri': 'spotify:artist:63yrD80RY3RNEM2YDpUpO8'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
# ...

# %%
result = sp.search("Home")
result
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Home&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rIaHuCIUu32uj2CjlEBN3'},
#        'href': 'https://api.spotify.com/v1/artists/6rIaHuCIUu32uj2CjlEBN3',
#        'id': '6rIaHuCIUu32uj2CjlEBN3',
#        'name': 'Mike Dimes',
#        'type': 'artist',
#        'uri': 'spotify:artist:6rIaHuCIUu32uj2CjlEBN3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
# ...

# %%
sp.album_tracks("3U1X1wd3lX7EteWYhS2hpT")
# Out:
# {'href': 'https://api.spotify.com/v1/albums/3U1X1wd3lX7EteWYhS2hpT/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#      'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#      'id': '6TIYQ3jFPwQSRmorSezPxX',
#      'name': 'Machine Gun Kelly',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#      'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#      'id': '3NPpFNZtSTHheNBaWC82rB',
#      'name': 'X Ambassadors',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/64M6ah0SkkRsnPGtGiRAbb'},
#      'href': 'https://api.spotify.com/v1/artists/64M6ah0SkkRsnPGtGiRAbb',
#      'id': '64M6ah0SkkRsnPGtGiRAbb',
# ...

# %%
sp.search("spotify:track:0OI7AFifLSoGzpb8bdBLLV")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=spotify%3Atrack%3A0OI7AFifLSoGzpb8bdBLLV&type=track&offset=0&limit=10',
#   'items': [],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
sp.audio_features("3XOalgusokruzA5ZBA2Qcb")
# Out:
# [{'danceability': 0.773,
#   'energy': 0.422,
#   'key': 1,
#   'loudness': -4.572,
#   'mode': 0,
#   'speechiness': 0.187,
#   'acousticness': 0.00783,
#   'instrumentalness': 0.00693,
#   'liveness': 0.129,
#   'valence': 0.488,
#   'tempo': 77.502,
#   'type': 'audio_features',
#   'id': '3XOalgusokruzA5ZBA2Qcb',
#   'uri': 'spotify:track:3XOalgusokruzA5ZBA2Qcb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3XOalgusokruzA5ZBA2Qcb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XOalgusokruzA5ZBA2Qcb',
#   'duration_ms': 136267,
#   'time_signature': 1}]

# %%
sp.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
# ...

# %%
sp.search("acoustic")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=acoustic&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5gw5ANPCVcxU0maLiGRzzP'},
#        'href': 'https://api.spotify.com/v1/artists/5gw5ANPCVcxU0maLiGRzzP',
#        'id': '5gw5ANPCVcxU0maLiGRzzP',
#        'name': 'Billy Raffoul',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gw5ANPCVcxU0maLiGRzzP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
# ...

# %%
sp.show("spotify:show:4rOoJ6Egrf8K2IrywzwOMk")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2IrywzwOMk with Params: {'market': None} returned 404 due to non existing id
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2IrywzwOMk
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# ...
